# %%
import pandas as pd

# %%
# Use pandas to read in the data
df = pd.read_html('https://fbref.com/en/matches/ddb91d97/Olympiacos-Fenerbahce-April-11-2024-Europa-Conference-League', attrs={'id': "stats_2fdb4aef_summary"})[0]

# %%
df
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                Player                  #             Nation
# 0      Ayoub El Kaabi                9.0             ma MAR
# 1    Youssef El-Arabi               11.0             ma MAR
# 2    Kostas Fortounis                7.0             gr GRE
# 3    Giorgos Masouras               19.0             gr GRE
# 4               Quini               18.0             es ESP
# 5      Stevan Jovetić               22.0             me MNE
# 6         André Horta                5.0             pt POR
# 7           Chiquinho                6.0             pt POR
# 8      Vicente Iborra                8.0             es ESP
# 9      Santiago Hezze               32.0             ar ARG
# 10   Francisco Ortega                3.0             ar ARG
# 11        David Carmo               16.0             ao ANG
# 12  Panagiotis Retsos               45.0             gr GRE
# 13            Rodinei               23.0             br BRA
# ...

# %%
# Use pandas to read in the data
df2 = pd.read_html('https://fbref.com/en/matches/ddb91d97/Olympiacos-Fenerbahce-April-11-2024-Europa-Conference-League', attrs={'id': "stats_ae1e2d7d_summary"})[0]
df2
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Player                  #             Nation
# 0            Edin Džeko                9.0             ba BIH
# 1   Sebastian Szymański               53.0             pl POL
# 2           Dušan Tadić               10.0             rs SRB
# 3             Miha Zajc               26.0             si SVN
# 4                  Fred               35.0             br BRA
# 5           Rade Krunić               33.0             ba BIH
# 6         İsmail Yüksek                5.0             tr TUR
# 7         İrfan Kahveci               17.0             tr TUR
# 8    Jayden Oosterwolde               24.0             nl NED
# 9        Ferdi Kadioglu                7.0             tr TUR
# 10       Çağlar Söyüncü                2.0             tr TUR
# 11        Rodrigo Becão               50.0             br BRA
# 12     Leonardo Bonucci               19.0             it ITA
# ...

# %%
df.columns = df.columns.droplevel()
df2.columns = df2.columns.droplevel()

# %%
# Extract desired rows
df_row = df.iloc[2]
df2_row = df2.iloc[2]

# Extract desired rows
df_row = df.iloc[2]
df2_row = df2.iloc[2]

# Create a new DataFrame by merging the extracted rows vertically
new_df = pd.concat([df_row, df2_row], axis=1).T

# Reset index for better clarity
new_df.reset_index(drop=True, inplace=True)

print(new_df)
# Out:
#              Player     #  Nation Pos     Age Min Gls Ast PK PKatt  ... SCA  \
# 0  Kostas Fortounis   7.0  gr GRE  LW  31-178  90   1   1  0     0  ...   8
# 1       Dušan Tadić  10.0  rs SRB  LM  35-143  90   1   0  1     1  ...   5
#
#   GCA Cmp Att  Cmp% PrgP Carries PrgC Att Succ
# 0   2  30  40  75.0    2      21    0   3    2
# 1   1  26  40  65.0    5      25    2   3    2
#
# [2 rows x 31 columns]

# %%
new_df
# Out:
#              Player     #  Nation Pos     Age Min Gls Ast PK PKatt  ... SCA  \
# 0  Kostas Fortounis   7.0  gr GRE  LW  31-178  90   1   1  0     0  ...   8
# 1       Dušan Tadić  10.0  rs SRB  LM  35-143  90   1   0  1     1  ...   5
#
#   GCA Cmp Att  Cmp% PrgP Carries PrgC Att Succ
# 0   2  30  40  75.0    2      21    0   3    2
# 1   1  26  40  65.0    5      25    2   3    2
#
# [2 rows x 31 columns]

# %%
cols = ['Player', 'Sh', 'SoT', 'Touches', 'Tkl', 'Int', 'Blocks', 'xG',
       'npxG', 'xAG', 'SCA', 'GCA', 'Cmp', 'Att', 'Cmp%', 'PrgP', 'Carries',
       'PrgC']

df = df[cols]
df
# Out:
#                Player  Sh  SoT  Touches  Tkl  Int  Blocks   xG  npxG  xAG  \
# 0      Ayoub El Kaabi   2    1       28    2    0       1  0.1   0.1  0.1
# 1    Youssef El-Arabi   0    0        3    0    0       0  0.0   0.0  0.0
# 2    Kostas Fortounis   2    1       48    0    1       2  0.1   0.1  0.5
# 3    Giorgos Masouras   1    1       30    3    0       4  0.0   0.0  0.1
# 4               Quini   0    0        5    0    0       0  0.0   0.0  0.0
# 5      Stevan Jovetić   2    1       33    3    0       1  0.2   0.2  0.0
# 6         André Horta   0    0        3    0    0       1  0.0   0.0  0.0
# 7           Chiquinho   1    1       40    0    1       2  0.1   0.1  0.0
# 8      Vicente Iborra   0    0        4    0    2       0  0.0   0.0  0.0
# 9      Santiago Hezze   0    0       35    1    3       1  0.0   0.0  0.0
# 10   Francisco Ortega   1    0       33    4    0       2  0.0   0.0  0.0
# 11        David Carmo   4    2       45    1    2       1  0.2   0.2  0.0
# ...

# %%
df2 = df2[cols]

# %%
df2
# Out:
#                  Player  Sh  SoT  Touches  Tkl  Int  Blocks   xG  npxG  xAG  \
# 0            Edin Džeko   3    2       38    1    0       1  0.2   0.2  0.2
# 1   Sebastian Szymański   3    1       20    2    0       1  0.2   0.2  0.4
# 2           Dušan Tadić   0    0       49    0    0       1  0.8   0.0  0.2
# 3             Miha Zajc   1    0       40    0    2       0  0.0   0.0  0.0
# 4                  Fred   1    1       28    1    0       0  0.0   0.0  0.1
# 5           Rade Krunić   1    1       41    0    1       0  0.1   0.1  0.0
# 6         İsmail Yüksek   0    0       21    0    2       1  0.0   0.0  0.0
# 7         İrfan Kahveci   2    1       47    0    0       1  0.4   0.4  0.1
# 8    Jayden Oosterwolde   1    0       30    3    1       0  0.1   0.1  0.0
# 9        Ferdi Kadioglu   0    0       38    1    0       0  0.0   0.0  0.0
# 10       Çağlar Söyüncü   0    0       64    0    1       1  0.0   0.0  0.0
# ...

# %%
new_df = new_df[cols]

# %%
ranges = [(0.0, 5.0), (0.0, 5.0), (0.0, 80), (0, 5), (0, 5), (0, 5), (0, 2), (0, 2), (0, 1), (0, 7), (0, 5),
          (0, 50), (0, 80), (0, 10), (0, 100), (0, 20), (0, 70), (0, 7)]

# %%
params = list(new_df.columns)
params = params[1:]
params
# Out:
# ['Sh',
#  'SoT',
#  'Touches',
#  'Tkl',
#  'Int',
#  'Blocks',
#  'xG',
#  'npxG',
#  'xAG',
#  'SCA',
#  'GCA',
#  'Cmp',
#  'Att',
#  'Att',
#  'Cmp%',
#  'PrgP',
#  'Carries',
#  'PrgC']

# %%
#add ranges to list of tuple pairs
a_values = []
b_values = []

# Drop the first column and assign it to a new DataFrame named 'data'
data = new_df.drop(columns=new_df.columns[0])

for x in range(len(new_df['Player'])):
    if new_df['Player'][x] == 'Kostas Fortounis':
        a_values = new_df.iloc[x].values.tolist()
    if new_df['Player'][x] == 'Dušan Tadić':
        b_values = new_df.iloc[x].values.tolist()

a_values = a_values[1:]
b_values = b_values[1:]

values = [a_values,b_values]

# %%
values
# Out:
# [[2, 1, 48, 0, 1, 2, 0.1, 0.1, 0.5, 8, 2, 30, 40, 3, 75.0, 2, 21, 0],
#  [0, 0, 49, 0, 0, 1, 0.8, 0.0, 0.2, 5, 1, 26, 40, 3, 65.0, 5, 25, 2]]

# %%
title = dict(
    title_name='Kostas Fortounis',
    title_color = 'red',
    subtitle_name = 'Olympiacos',
    subtitle_color = "red",
    title_name_2 = 'Dušan Tadić',
    title_color_2 = 'yellow',
    subtitle_name_2 = 'Fenerbahce',
    subtitle_color_2 = 'yellow',
    title_fontsize = 18,
    subtitle_fontsize=15
)

# %%
pip install soccerplots

# %%
from soccerplots.radar_chart import Radar

# %%
radar = Radar()

fig,ax = radar.plot_radar(ranges=ranges,params=params,values=values,
                         radar_color=['red', 'yellow'],
                         alphas=[.75,.6],title=title,
                         compare=True)
